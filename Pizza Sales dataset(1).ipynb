# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
data1=pd.read_csv("Downloads/order_details.csv")
data1
# Out:
#        order_details_id  order_id       pizza_id  quantity
# 0                     1         1     hawaiian_m         1
# 1                     2         2  classic_dlx_m         1
# 2                     3         2  five_cheese_l         1
# 3                     4         2    ital_supr_l         1
# 4                     5         2     mexicana_m         1
# ...                 ...       ...            ...       ...
# 48615             48616     21348  ckn_alfredo_m         1
# 48616             48617     21348  four_cheese_l         1
# 48617             48618     21348   napolitana_s         1
# 48618             48619     21349     mexicana_l         1
# 48619             48620     21350      bbq_ckn_s         1
#
# [48620 rows x 4 columns]

# %%
data2=pd.read_csv("Downloads/orders.csv")
data2
# Out:
#        order_id        date      time
# 0             1  2015-01-01  11:38:36
# 1             2  2015-01-01  11:57:40
# 2             3  2015-01-01  12:12:28
# 3             4  2015-01-01  12:16:31
# 4             5  2015-01-01  12:21:30
# ...         ...         ...       ...
# 21345     21346  2015-12-31  20:51:07
# 21346     21347  2015-12-31  21:14:37
# 21347     21348  2015-12-31  21:23:10
# 21348     21349  2015-12-31  22:09:54
# 21349     21350  2015-12-31  23:02:05
#
# [21350 rows x 3 columns]

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21350 entries, 0 to 21349
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   order_id  21350 non-null  int64
#  1   date      21350 non-null  object
#  2   time      21350 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 500.5+ KB

# %%
data2["date"]=pd.to_datetime(data2["date"]) #to convert the date to a datetime

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21350 entries, 0 to 21349
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   order_id  21350 non-null  int64
#  1   date      21350 non-null  datetime64[ns]
#  2   time      21350 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 500.5+ KB

# %%
df3=pd.merge(data1,data2,on="order_id",how="inner") #used merge method to combine the two dataframe
df3
# Out:
#        order_details_id  order_id       pizza_id  quantity       date  \
# 0                     1         1     hawaiian_m         1 2015-01-01
# 1                     2         2  classic_dlx_m         1 2015-01-01
# 2                     3         2  five_cheese_l         1 2015-01-01
# 3                     4         2    ital_supr_l         1 2015-01-01
# 4                     5         2     mexicana_m         1 2015-01-01
# ...                 ...       ...            ...       ...        ...
# 48615             48616     21348  ckn_alfredo_m         1 2015-12-31
# 48616             48617     21348  four_cheese_l         1 2015-12-31
# 48617             48618     21348   napolitana_s         1 2015-12-31
# 48618             48619     21349     mexicana_l         1 2015-12-31
# 48619             48620     21350      bbq_ckn_s         1 2015-12-31
#
#            time
# 0      11:38:36
# 1      11:57:40
# 2      11:57:40
# 3      11:57:40
# 4      11:57:40
# ...         ...
# ...

# %%
data3=pd.read_csv("Downloads/pizza_types2.csv")
data3
# Out:
#    pizza_type_id                                        name category  \
# 0        bbq_ckn                  The Barbecue Chicken Pizza  Chicken
# 1       cali_ckn                The California Chicken Pizza  Chicken
# 2    ckn_alfredo                   The Chicken Alfredo Pizza  Chicken
# 3      ckn_pesto                     The Chicken Pesto Pizza  Chicken
# 4     southw_ckn                 The Southwest Chicken Pizza  Chicken
# 5       thai_ckn                      The Thai Chicken Pizza  Chicken
# 6       big_meat                          The Big Meat Pizza  Classic
# 7    classic_dlx                    The Classic Deluxe Pizza  Classic
# 8       hawaiian                          The Hawaiian Pizza  Classic
# 9    ital_cpcllo                 The Italian Capocollo Pizza  Classic
# 10    napolitana                        The Napolitana Pizza  Classic
# 11   pep_msh_pep  The Pepperoni, Mushroom, and Peppers Pizza  Classic
# ...

# %%
data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   pizza_type_id  32 non-null     object
#  1   name           32 non-null     object
#  2   category       32 non-null     object
#  3   ingredients    32 non-null     object
# dtypes: object(4)
# memory usage: 1.1+ KB

# %%
data4=pd.read_csv("Downloads/pizzas.csv")
data4
# Out:
#          pizza_id pizza_type_id size  price
# 0       bbq_ckn_s       bbq_ckn    S  12.75
# 1       bbq_ckn_m       bbq_ckn    M  16.75
# 2       bbq_ckn_l       bbq_ckn    L  20.75
# 3      cali_ckn_s      cali_ckn    S  12.75
# 4      cali_ckn_m      cali_ckn    M  16.75
# ..            ...           ...  ...    ...
# 91  spinach_fet_m   spinach_fet    M  16.00
# 92  spinach_fet_l   spinach_fet    L  20.25
# 93   veggie_veg_s    veggie_veg    S  12.00
# 94   veggie_veg_m    veggie_veg    M  16.00
# 95   veggie_veg_l    veggie_veg    L  20.25
#
# [96 rows x 4 columns]

# %%
data4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   pizza_id       96 non-null     object
#  1   pizza_type_id  96 non-null     object
#  2   size           96 non-null     object
#  3   price          96 non-null     float64
# dtypes: float64(1), object(3)
# memory usage: 3.1+ KB

# %%
data4.head()
# Out:
#      pizza_id pizza_type_id size  price
# 0   bbq_ckn_s       bbq_ckn    S  12.75
# 1   bbq_ckn_m       bbq_ckn    M  16.75
# 2   bbq_ckn_l       bbq_ckn    L  20.75
# 3  cali_ckn_s      cali_ckn    S  12.75
# 4  cali_ckn_m      cali_ckn    M  16.75

# %%
df5=pd.merge(data3,data4,on="pizza_type_id")
df5
# Out:
#    pizza_type_id                               name category  \
# 0        bbq_ckn         The Barbecue Chicken Pizza  Chicken
# 1        bbq_ckn         The Barbecue Chicken Pizza  Chicken
# 2        bbq_ckn         The Barbecue Chicken Pizza  Chicken
# 3       cali_ckn       The California Chicken Pizza  Chicken
# 4       cali_ckn       The California Chicken Pizza  Chicken
# ..           ...                                ...      ...
# 91   spinach_fet         The Spinach and Feta Pizza   Veggie
# 92   spinach_fet         The Spinach and Feta Pizza   Veggie
# 93    veggie_veg  The Vegetables + Vegetables Pizza   Veggie
# 94    veggie_veg  The Vegetables + Vegetables Pizza   Veggie
# 95    veggie_veg  The Vegetables + Vegetables Pizza   Veggie
#
#                                           ingredients       pizza_id size  \
# 0   Barbecued Chicken, Red Peppers, Green Peppers,...      bbq_ckn_s    S
# 1   Barbecued Chicken, Red Peppers, Green Peppers,...      bbq_ckn_m    M
# ...

# %% [markdown]
# ## Used merge method to join the dataframe

# %%
data5=pd.merge(df3,df5,on="pizza_id",how="inner")
data5
# Out:
#        order_details_id  order_id       pizza_id  quantity       date  \
# 0                     1         1     hawaiian_m         1 2015-01-01
# 1                     2         2  classic_dlx_m         1 2015-01-01
# 2                     3         2  five_cheese_l         1 2015-01-01
# 3                     4         2    ital_supr_l         1 2015-01-01
# 4                     5         2     mexicana_m         1 2015-01-01
# ...                 ...       ...            ...       ...        ...
# 48615             48616     21348  ckn_alfredo_m         1 2015-12-31
# 48616             48617     21348  four_cheese_l         1 2015-12-31
# 48617             48618     21348   napolitana_s         1 2015-12-31
# 48618             48619     21349     mexicana_l         1 2015-12-31
# 48619             48620     21350      bbq_ckn_s         1 2015-12-31
#
#            time pizza_type_id                        name category  \
# ...

# %%
data5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48620 entries, 0 to 48619
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_details_id  48620 non-null  int64
#  1   order_id          48620 non-null  int64
#  2   pizza_id          48620 non-null  object
#  3   quantity          48620 non-null  int64
#  4   date              48620 non-null  datetime64[ns]
#  5   time              48620 non-null  object
#  6   pizza_type_id     48620 non-null  object
#  7   name              48620 non-null  object
#  8   category          48620 non-null  object
#  9   ingredients       48620 non-null  object
#  10  size              48620 non-null  object
#  11  price             48620 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(7)
# memory usage: 4.5+ MB

# %%
data5["date"].value_counts()
# Out:
# date
# 2015-11-26    261
# 2015-11-27    259
# 2015-10-15    258
# 2015-07-04    233
# 2015-07-03    207
#              ...
# 2015-12-27     87
# 2015-11-22     82
# 2015-12-29     77
# 2015-03-22     76
# 2015-12-30     73
# Name: count, Length: 358, dtype: int64

# %%
data5.isna().sum() #to get the total number of null values,I successfully removed all the null values
# Out:
# order_details_id    0
# order_id            0
# pizza_id            0
# quantity            0
# date                0
# time                0
# pizza_type_id       0
# name                0
# category            0
# ingredients         0
# size                0
# price               0
# dtype: int64

# %% [markdown]
# ## Drop the Null Values in Date

# %%
data5= data5.dropna(subset=["date"])
data5.isna().sum()
# Out:
# order_details_id    0
# order_id            0
# pizza_id            0
# quantity            0
# date                0
# time                0
# pizza_type_id       0
# name                0
# category            0
# ingredients         0
# size                0
# price               0
# dtype: int64

# %%
data5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48620 entries, 0 to 48619
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_details_id  48620 non-null  int64
#  1   order_id          48620 non-null  int64
#  2   pizza_id          48620 non-null  object
#  3   quantity          48620 non-null  int64
#  4   date              48620 non-null  datetime64[ns]
#  5   time              48620 non-null  object
#  6   pizza_type_id     48620 non-null  object
#  7   name              48620 non-null  object
#  8   category          48620 non-null  object
#  9   ingredients       48620 non-null  object
#  10  size              48620 non-null  object
#  11  price             48620 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(7)
# memory usage: 4.5+ MB

# %% [markdown]
# ## Drop the Duplicate columns

# %%
data5.duplicated().sum() # just to check if there's a duplicate column
# Out:
# 0

# %% [markdown]
# ## Filling the Null Values with"Unknown"

# %%
data5["pizza_type_id"]=data5["pizza_type_id"].fillna("Unknown")
data5["name"]=data5["name"].fillna("Unknown")
data5["category"]=data5["category"].fillna("Unknown")
data5["ingredients"]=data5["ingredients"].fillna("Unknown")
data5["pizza_id"]=data5["pizza_id"].fillna("Unknown")
data5["pizza_type_id"]=data5["pizza_type_id"].fillna("Unknown")
data5["size"]=data5["size"].fillna("Unknown")

# %%
data5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48620 entries, 0 to 48619
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_details_id  48620 non-null  int64
#  1   order_id          48620 non-null  int64
#  2   pizza_id          48620 non-null  object
#  3   quantity          48620 non-null  int64
#  4   date              48620 non-null  datetime64[ns]
#  5   time              48620 non-null  object
#  6   pizza_type_id     48620 non-null  object
#  7   name              48620 non-null  object
#  8   category          48620 non-null  object
#  9   ingredients       48620 non-null  object
#  10  size              48620 non-null  object
#  11  price             48620 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(7)
# memory usage: 4.5+ MB

# %% [markdown]
# ## Fill the null values with the mean

# %%
data5["price"] = data5["price"].fillna(data5["price"].mean())

# %%
data5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48620 entries, 0 to 48619
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_details_id  48620 non-null  int64
#  1   order_id          48620 non-null  int64
#  2   pizza_id          48620 non-null  object
#  3   quantity          48620 non-null  int64
#  4   date              48620 non-null  datetime64[ns]
#  5   time              48620 non-null  object
#  6   pizza_type_id     48620 non-null  object
#  7   name              48620 non-null  object
#  8   category          48620 non-null  object
#  9   ingredients       48620 non-null  object
#  10  size              48620 non-null  object
#  11  price             48620 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(7)
# memory usage: 4.5+ MB

# %%
data5.head(10)
# Out:
#    order_details_id  order_id       pizza_id  quantity       date      time  \
# 0                 1         1     hawaiian_m         1 2015-01-01  11:38:36
# 1                 2         2  classic_dlx_m         1 2015-01-01  11:57:40
# 2                 3         2  five_cheese_l         1 2015-01-01  11:57:40
# 3                 4         2    ital_supr_l         1 2015-01-01  11:57:40
# 4                 5         2     mexicana_m         1 2015-01-01  11:57:40
# 5                 6         2     thai_ckn_l         1 2015-01-01  11:57:40
# 6                 7         3    ital_supr_m         1 2015-01-01  12:12:28
# 7                 8         3   prsc_argla_l         1 2015-01-01  12:12:28
# 8                 9         4    ital_supr_m         1 2015-01-01  12:16:31
# 9                10         5    ital_supr_m         1 2015-01-01  12:21:30
#
#   pizza_type_id                              name category  \
# 0      hawaiian                The Hawaiian Pizza  Classic
# ...

# %%
data5.sample(10)
# Out:
#        order_details_id  order_id        pizza_id  quantity       date  \
# 18856             18857      8281     calabrese_m         1 2015-05-19
# 13548             13549      5944   ital_veggie_l         1 2015-04-10
# 20825             20826      9135   spinach_fet_l         1 2015-06-02
# 25807             25808     11358       bbq_ckn_l         1 2015-07-09
# 12594             12595      5534    spicy_ital_l         1 2015-04-03
# 29003             29004     12798    prsc_argla_l         1 2015-08-01
# 23428             23429     10297  peppr_salami_l         1 2015-06-22
# 28880             28881     12738   four_cheese_l         1 2015-08-01
# 34330             34331     15150      mexicana_m         1 2015-09-10
# 34756             34757     15345    spin_pesto_l         1 2015-09-13
#
#            time pizza_type_id                              name category  \
# 18856  12:03:38     calabrese               The Calabrese Pizza  Supreme
# ...

# %% [markdown]
# ## Total Revenue

# %%
data5["revenue"]=data5["quantity"]*data5["price"]
data5["revenue"]
# Out:
# 0        13.25
# 1        16.00
# 2        18.50
# 3        20.75
# 4        16.00
#          ...
# 48615    16.75
# 48616    17.95
# 48617    12.00
# 48618    20.25
# 48619    12.75
# Name: revenue, Length: 48620, dtype: float64

# %%
data5.groupby("pizza_type_id")["revenue"].sum().reset_index()
# Out:
#    pizza_type_id       revenue
# 0        bbq_ckn  1.939964e+09
# 1       big_meat  1.481145e+09
# 2     brie_carre  3.925728e+08
# 3      calabrese  7.581563e+08
# 4       cali_ckn  1.882714e+09
# 5    ckn_alfredo  8.015028e+08
# 6      ckn_pesto  7.859635e+08
# 7    classic_dlx  1.975950e+09
# 8    five_cheese  1.111472e+09
# 9    four_cheese  1.513041e+09
# 10  green_garden  8.072279e+08
# 11      hawaiian  1.938328e+09
# 12   ital_cpcllo  1.156454e+09
# 13     ital_supr  1.512223e+09
# 14   ital_veggie  7.974135e+08
# 15  mediterraneo  7.548848e+08
# 16      mexicana  1.190804e+09
# 17    napolitana  1.186715e+09
# 18   pep_msh_pep  1.097568e+09
# 19     pepperoni  1.937510e+09
# 20  peppr_salami  1.162997e+09
# 21    prsc_argla  1.167904e+09
# 22      sicilian  1.543302e+09
# 23   soppressata  7.826921e+08
# 24    southw_ckn  1.541666e+09
# 25    spicy_ital  1.543302e+09
# 26    spin_pesto  7.826921e+08
# 27   spinach_fet  1.171176e+09
# 28  spinach_supr  7.687884e+08
# ...

# %%
plt.bar(data5["pizza_type_id"],data5["revenue"])
plt.title("Revenue by Pizza Type")
plt.xticks(rotation=90)
plt.xlabel("Pizza Type")
plt.ylabel("Revenue")
plt.show()

# %% [markdown]
# ## Total Quantity

# %%
data5["total_quantity"]=data5["quantity"].sum()
total_quantity
# Out:
# 49574

# %%
data5.groupby("quantity")["name"].sum().reset_index()
# Out:
#    quantity                                               name
# 0         1  The Hawaiian PizzaThe Classic Deluxe PizzaThe ...
# 1         2  The Mediterranean PizzaThe Barbecue Chicken Pi...
# 2         3  The Spicy Italian PizzaThe Barbecue Chicken Pi...
# 3         4  The Big Meat PizzaThe Big Meat PizzaThe Califo...

# %%
plt.bar(data5["name"],data5["quantity"])
plt.title("Quantity by Pizza name")
plt.xticks(rotation=90)
plt.xlabel("pizza name")
plt.ylabel("Quantity")
plt.show()

# %% [markdown]
# ## Total Orders

# %%
total_order=data5["order_id"].sum()
total_order
# Out:
# 520305946

# %%
data5.groupby("order_id")["category"].sum().reset_index().head(10)
# Out:
#    order_id                                           category
# 0         1                                            Classic
# 1         2                  ClassicVeggieSupremeVeggieChicken
# 2         3                                     SupremeSupreme
# 3         4                                            Supreme
# 4         5                                            Supreme
# 5         6                                     ChickenClassic
# 6         7                                            Supreme
# 7         8                                            Supreme
# 8         9  ClassicVeggieClassicSupremeSupremeVeggieSuprem...
# 9        10                                      VeggieChicken

# %%
plt.bar(data5["category"],data5["order_id"])
plt.title(" Order ID by Quantity")
plt.xlabel("Category")
plt.ylabel("Order ID")
plt.show()

# %% [markdown]
# ## Category of pizza type

# %%
no_pizza_type1=data5["category"].value_counts()
no_pizza_type1
# Out:
# category
# Classic    14579
# Supreme    11777
# Veggie     11449
# Chicken    10815
# Name: count, dtype: int64

# %%
plt.bar(no_pizza_type1.index,no_pizza_type1.values)
plt.title("Category of Pizza type",fontsize=20)
plt.show()

# %% [markdown]
# ## Number of Pizza Type

# %%
no_pizza_type=data5["name"].count()

no_pizza_type
# Out:
# 48620

# %%
plt.hist(no_pizza_type,bins=10)
plt.title("Distribution of No. of Pizza Type")
plt.xlabel("No. of Pizza Type")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ## Average Pizza price

# %%
average_price=data5["price"].mean()
average_price
# Out:
# 16.494132044426163

# %%
plt.hist(average_price,bins=10)
plt.title("Distribution of Average Pizza Price")
plt.xlabel("Average Price")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ## Peak Hours of Sales

# %%
data5["Hour"]=pd.to_datetime(data5["time"],format="%H:%M:%S").dt.hour
peak_hours=data5.groupby("Hour")["price"].sum().reset_index()
peak_hours
# Out:
#     Hour      price
# 0      9      83.00
# 1     10     285.70
# 2     11   43978.80
# 3     12  108047.75
# 4     13  102550.95
# 5     14   57650.20
# 6     15   52231.30
# 7     16   69129.40
# 8     17   85128.10
# 9     18   88334.20
# 10    19   71665.50
# 11    20   57420.75
# 12    21   41769.30
# 13    22   22548.40
# 14    23    1121.35

# %%
plt.plot(peak_hours["Hour"],peak_hours["price"])
plt.title("Peak Hours of Sales",fontsize=20)
plt.xlabel("Hours")
plt.ylabel("Prices")
plt.show()

# %% [markdown]
# ## Total Sales Per Day

# %%
data5["Day"]=data5["date"].dt.day_name() #I extracted day from the date column
total_sales_day=data5.groupby("Day")["price"].sum().reset_index()
total_sales_day
# Out:
#          Day      price
# 0     Friday  133773.90
# 1     Monday  105357.15
# 2   Saturday  120865.30
# 3     Sunday   97264.75
# 4   Thursday  120912.45
# 5    Tuesday  111764.70
# 6  Wednesday  112006.45

# %%
plt.bar(total_sales_day["Day"],total_sales_day["price"])
plt.xticks(rotation=45)
plt.title("Total Sales Per Day",fontsize=20)
plt.xlabel("Days")
plt.ylabel("price")
plt.show()

# %% [markdown]
# ## Top 5 bestselling pizzas

# %%
Top_selling_pizza=data5.groupby("name")["quantity"].sum().nlargest(5).reset_index()
Top_selling_pizza
# Out:
#                          name  quantity
# 0    The Classic Deluxe Pizza      2453
# 1  The Barbecue Chicken Pizza      2432
# 2          The Hawaiian Pizza      2422
# 3         The Pepperoni Pizza      2418
# 4      The Thai Chicken Pizza      2371

# %%
plt.plot(Top_selling_pizza["name"],Top_selling_pizza["quantity"])
plt.title("Top 5 Bestselling Pizzas")
plt.xticks(rotation=45)
plt.xlabel("Pizza name")
plt.ylabel("Quantity")
plt.show()

# %% [markdown]
# ## Sales by the Month

# %%
data5["Month"]=data5["date"].dt.month_name() #I extracted month from the date column
data5["Month"]
# Out:
# 0         January
# 1         January
# 2         January
# 3         January
# 4         January
#            ...
# 48615    December
# 48616    December
# 48617    December
# 48618    December
# 48619    December
# Name: Month, Length: 48620, dtype: object

# %%
monthly_sales=data5.groupby("Month")["price"].sum().reset_index().sort_values(by="Month")
monthly_sales
# Out:
#         Month     price
# 0       April  67286.20
# 1      August  67068.80
# 2    December  63450.00
# 3    February  64067.40
# 4     January  68472.70
# 5        July  71027.45
# 6        June  66796.30
# 7       March  69198.00
# 8         May  69939.35
# 9    November  69054.00
# 10    October  62566.50
# 11  September  63018.00

# %%
plt.plot(monthly_sales["Month"],monthly_sales["price"])
plt.title("Sales by Month",fontsize=20)
plt.xlabel("Months")
plt.ylabel("Price")
plt.xticks(rotation=45)
plt.show()

# %%
least_selling_pizzas=data5.groupby("name")["quantity"].sum().nsmallest(10).reset_index()
least_selling_pizzas
# Out:
#                            name  quantity
# 0          The Brie Carre Pizza       490
# 1       The Mediterranean Pizza       934
# 2           The Calabrese Pizza       937
# 3     The Spinach Supreme Pizza       950
# 4         The Soppressata Pizza       961
# 5       The Spinach Pesto Pizza       970
# 6       The Chicken Pesto Pizza       973
# 7  The Italian Vegetables Pizza       981
# 8     The Chicken Alfredo Pizza       987
# 9        The Green Garden Pizza       997

# %%
plt.plot(least_selling_pizzas["name"],least_selling_pizzas["quantity"])
plt.title("Least Selling Pizzas")
plt.xticks(rotation=45)
plt.xlabel("Pizza name")
plt.ylabel("Quantity Sold")
plt.show()
